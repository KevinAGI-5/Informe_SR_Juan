# %% [markdown]
# <a href="https://colab.research.google.com/github/KevinAGI-5/Informe_SR_Juan/blob/main/Untitled2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# 1. Análisis de facturación

# %%
precioTotal1 = tienda['Precio'].sum()
precioTotal1
# Out:
# np.float64(1150880400.0)

# %%
precioTotal2 = tienda2['Precio'].sum()
precioTotal2
# Out:
# np.float64(1116343500.0)

# %%
precioTotal3 = tienda3['Precio'].sum()
precioTotal3
# Out:
# np.float64(1098019600.0)

# %%
precioTotal4 = tienda4['Precio'].sum()
precioTotal4
# Out:
# np.float64(1038375700.0)

# %% [markdown]
# Graficos

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [precioTotal1, precioTotal2, precioTotal3, precioTotal4],color="green")
for x, y in zip(['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'], [precioTotal1, precioTotal2, precioTotal3, precioTotal4]):
    plt.text(x, y, str(y), ha='center', va='bottom')

plt.xlabel('Tiendas')
plt.ylabel('Ingresos')
plt.title('Ingresos por Tienda')
plt.show()

# %% [markdown]
# 2. Ventas por categoría

# %%
Venta_categoria1 = tienda.groupby('Categoría del Producto')['Producto'].count().reset_index(name="Ventas")
Venta_categoria1
# Out:
#     Categoría del Producto  Ventas
# 0  Artículos para el hogar     171
# 1     Deportes y diversión     284
# 2        Electrodomésticos     312
# 3             Electrónicos     448
# 4   Instrumentos musicales     182
# 5                 Juguetes     324
# 6                   Libros     173
# 7                  Muebles     465

# %%
Venta_categoria2 = tienda.groupby('Categoría del Producto')['Producto'].count().reset_index(name="Ventas")
Venta_categoria2
# Out:
#     Categoría del Producto  Ventas
# 0  Artículos para el hogar     171
# 1     Deportes y diversión     284
# 2        Electrodomésticos     312
# 3             Electrónicos     448
# 4   Instrumentos musicales     182
# 5                 Juguetes     324
# 6                   Libros     173
# 7                  Muebles     465

# %%
Venta_categoria3 = tienda.groupby('Categoría del Producto')['Producto'].count().reset_index(name="Ventas")
Venta_categoria3
# Out:
#     Categoría del Producto  Ventas
# 0  Artículos para el hogar     171
# 1     Deportes y diversión     284
# 2        Electrodomésticos     312
# 3             Electrónicos     448
# 4   Instrumentos musicales     182
# 5                 Juguetes     324
# 6                   Libros     173
# 7                  Muebles     465

# %%
Venta_categoria4 = tienda.groupby('Categoría del Producto')['Producto'].count().reset_index(name="Ventas")
Venta_categoria4
# Out:
#     Categoría del Producto  Ventas
# 0  Artículos para el hogar     171
# 1     Deportes y diversión     284
# 2        Electrodomésticos     312
# 3             Electrónicos     448
# 4   Instrumentos musicales     182
# 5                 Juguetes     324
# 6                   Libros     173
# 7                  Muebles     465

# %% [markdown]
# graficos

# %%
ventas_totales_categoria = pd.concat([
    Venta_categoria1,
    Venta_categoria2,
    Venta_categoria3,
    Venta_categoria4
]).groupby('Categoría del Producto')['Ventas'].sum().reset_index()

plt.figure(figsize=(10, 8))
plt.pie(ventas_totales_categoria['Ventas'], labels=ventas_totales_categoria['Categoría del Producto'], autopct='%1.0f%%', startangle=50)
plt.title('Ventas Totales por Categoría de Producto en Todas las Tiendas')
plt.axis('equal')
plt.show()

# %% [markdown]
# 3. Calificación promedio de la tienda

# %%
promedio1 = tienda['Calificación'].mean()
print(f"Tienda 1: {promedio1:.2f}");

promedio2 = tienda2['Calificación'].mean()
print(f"Tienda 2: {promedio2:.2f}");
promedio3 = tienda3['Calificación'].mean()
print(f"Tienda 3: {promedio3:.2f}");
promedio4 = tienda4['Calificación'].mean()
print(f"Tienda 4: {promedio4:.2f}");
# Out:
# Tienda 1: 3.98
# Tienda 2: 4.04
# Tienda 3: 4.05
# Tienda 4: 4.00

# %% [markdown]
# grafica

# %%
promedio = [promedio1, promedio2, promedio3, promedio4]
tienda = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']
data = {'Tienda': tienda, 'Promedio': promedio}
df = pd.DataFrame(data)

ax = df.plot(kind='line', x='Tienda', y='Promedio', marker='o')


for i, txt in enumerate(df['Promedio']):
    ax.annotate(f'{txt:.2f}', (i, txt), textcoords="offset points", xytext=(0,10), ha='center')

plt.title('Calificación Promedio por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Promedio de Calificación')
plt.grid(True)
plt.show()

# %% [markdown]
# 4. Productos más y menos vendidos

# %%
import pandas as pd

df_tienda = pd.DataFrame(tienda)
df_tienda2 = pd.DataFrame(tienda2)
df_tienda3 = pd.DataFrame(tienda3)
df_tienda4 = pd.DataFrame(tienda4)

indice_producto = 2


df_tienda.columns.values[indice_producto] = 'Producto'

ventas = df_tienda.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("¡Éxito! Aquí están tus ventas en la Tienda 1:")
print(ventas)

ventas = df_tienda2.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("¡Éxito! Aquí están tus ventas en la Tienda 2:")
print(ventas)

ventas = df_tienda3.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("¡Éxito! Aquí están tus ventas en la Tienda 3:")
print(ventas)

ventas = df_tienda4.groupby('Producto')['Producto'].count().sort_values(ascending=False)
print("¡Éxito! Aquí están tus ventas en la Tienda 4:")
print(ventas)
# Out:
# ¡Éxito! Aquí están tus ventas en la Tienda 1:
# Producto
# Armario                        60
# TV LED UHD 4K                  60
# Microondas                     60
# Secadora de ropa               58
# Mesa de noche                  56
# Bloques de construcción        56
# Balón de baloncesto            55
# Bicicleta                      54
# Impresora                      54
# Vaso térmico                   54
# Refrigerador                   54
# Batería                        53
# Cubertería                     52
# Carrito de control remoto      52
# Modelado predictivo            51
# Auriculares                    50
# Ajedrez de madera              49
# Iphone 15                      49
# Lavavajillas                   48
# Guitarra eléctrica             47
# Lavadora de ropa               47
# Silla de oficina               46
# Sofá reclinable                46
# Guitarra acústica              46
# Estufa                         45
# Mesa de centro                 44
# ...

# %% [markdown]
# Graficos

# %%
import numpy as np

def get_product_sales_data(df, store_name):
    ventas = df.groupby('Producto')['Producto'].count().sort_values(ascending=False)
    mas_vendido_name = ventas.idxmax()
    mas_vendido_count = ventas.max()
    menos_vendido_name = ventas.idxmin()
    menos_vendido_count = ventas.min()
    return {
        'Store': store_name,
        'Producto': [mas_vendido_name, menos_vendido_name],
        'Cantidad': [mas_vendido_count, menos_vendido_count],
        'Tipo': ['Más Vendido', 'Menos Vendido']
    }

tienda1_df = pd.read_csv(url)

data_tienda1 = get_product_sales_data(tienda1_df, 'Tienda 1')
data_tienda2 = get_product_sales_data(tienda2, 'Tienda 2')
data_tienda3 = get_product_sales_data(tienda3, 'Tienda 3')
data_tienda4 = get_product_sales_data(tienda4, 'Tienda 4')


combined_data = pd.concat([
    pd.DataFrame(data_tienda1),
    pd.DataFrame(data_tienda2),
    pd.DataFrame(data_tienda3),
    pd.DataFrame(data_tienda4)
]).reset_index(drop=True)


fig, ax = plt.subplots(figsize=(14, 5))

stores = combined_data['Store'].unique()
product_types = combined_data['Tipo'].unique()

width = 0.35
ind = np.arange(len(stores))


mas_vendido_counts = [combined_data[(combined_data['Store'] == s) & (combined_data['Tipo'] == 'Más Vendido')]['Cantidad'].iloc[0] for s in stores]
rects1 = ax.bar(ind - width/2, mas_vendido_counts, width, label='Más Vendido', color='skyblue')

menos_vendido_counts = [combined_data[(combined_data['Store'] == s) & (combined_data['Tipo'] == 'Menos Vendido')]['Cantidad'].iloc[0] for s in stores]
rects2 = ax.bar(ind + width/2, menos_vendido_counts, width, label='Menos Vendido', color='lightcoral')


for i, store in enumerate(stores):
    mas_vendido_product = combined_data[(combined_data['Store'] == store) & (combined_data['Tipo'] == 'Más Vendido')]['Producto'].iloc[0]
    menos_vendido_product = combined_data[(combined_data['Store'] == store) & (combined_data['Tipo'] == 'Menos Vendido')]['Producto'].iloc[0]

    ax.text(ind[i] - width/2, mas_vendido_counts[i] + 1, f'{mas_vendido_counts[i]}', ha='center', va='bottom', fontsize=9, color='black')
    ax.text(ind[i] + width/2, menos_vendido_counts[i] + 1, f'{menos_vendido_counts[i]}', ha='center', va='bottom', fontsize=9, color='black')


    ax.text(ind[i] - width/2, mas_vendido_counts[i] - 10, f'{mas_vendido_product}', ha='center', va='top', fontsize=8, color='darkblue', rotation=45)
    ax.text(ind[i] + width/2, menos_vendido_counts[i] - 10, f'{menos_vendido_product}', ha='center', va='top', fontsize=8, color='darkred', rotation=45)


ax.set_ylabel('Cantidad de Ventas')
ax.set_title('Productos Más y Menos Vendidos por Tienda')
ax.set_xticks(ind)
ax.set_xticklabels(stores)
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()
plt.show()

# %% [markdown]
# 5. Envío promedio por tienda

# %%
df_tienda = pd.DataFrame(tienda)

costo_envio1 = df_tienda['Costo de envío'].mean()
print(f"la Tienda 1, tiene un costo de envio de: {costo_envio1:.2f}")

costo_envio2 = df_tienda2['Costo de envío'].mean()
print(f"la Tienda 2, tiene un costo de envio de: {costo_envio2:.2f}")

costo_envio3 = df_tienda3['Costo de envío'].mean()
print(f"la Tienda 3, tiene un costo de envio de: {costo_envio3:.2f}")

costo_envio4 = df_tienda4['Costo de envío'].mean()
print(f"la Tienda 4, tiene un costo de envio de: {costo_envio4:.2f}")
# Out:
# la Tienda 1, tiene un costo de envio de: 26018.61
# la Tienda 2, tiene un costo de envio de: 25216.24
# la Tienda 3, tiene un costo de envio de: 24805.68
# la Tienda 4, tiene un costo de envio de: 23459.46

# %% [markdown]
# GRAFICOS

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np


df_costos = pd.DataFrame({
    'Tienda': ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4'],
    'Costo Promedio de Envío': [costo_envio1, costo_envio2, costo_envio3, costo_envio4]
})

plt.figure(figsize=(12, 5))

stores = df_costos['Tienda']
costs = df_costos['Costo Promedio de Envío']
x_positions = np.arange(len(stores))
colors = ['skyblue', 'lightcoral', 'lightgreen', 'gold']


plt.bar(x_positions, costs, color=colors, alpha=0.7, label='Costo Promedio de Envío')


plt.plot(x_positions, costs, color='red', linestyle='-', marker='o', markersize=8, linewidth=2, label='Tendencia de Costo')


for i, cost in enumerate(costs):
    plt.text(x_positions[i], cost, f'{cost:.2f}', ha='center', va='bottom', fontsize=10, color='black')

plt.xticks(x_positions, stores)
plt.xlabel('Tiendas', fontsize=12)
plt.ylabel('Costo Promedio de Envío', fontsize=12)
plt.title('Costo Promedio de Envío por Tienda (Columnas y Línea)', fontsize=14)
plt.legend(title='Elemento', loc='upper right')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.ylim(bottom=0)
plt.tight_layout()
plt.show()

# %% [markdown]
# INFORME

# %% [markdown]
# Diagnóstico de Rendimiento Comercial y Selección Estratégica1. IntroducciónEl presente documento expone un análisis comparativo de cuatro unidades de negocio (Tiendas 1 a 4) con el fin de determinar la viabilidad comercial para los productos del Sr. Juan.
#  Se han evaluado indicadores clave de rendimiento (KPIs) como la facturación total, la penetración por categoría, los niveles de satisfacción del consumidor (Rating), el comportamiento del inventario (Best/Worst sellers) y la eficiencia logística en costos de envío2.
#
#
# Ingresos Totales
#
#
#  Tienda 1: $1,150,880,400 (Líder en facturación)
#
#  Tienda 2: $1,116,343,500
#
#  Tienda 3: $1,098,019,600
#
#  Tienda 4: $1,038,375,700 (Desempeño base)
#
#  Diagnóstico: La Tienda 1 se posiciona como la unidad de mayor tracción económica, superando al resto de las sucursales en volumen monetario total.
#
#  Comportamiento del Mercado por Categorías
#
#  El análisis de la mezcla de productos revela una tendencia de consumo clara en todas las sedes:
#  Segmentos de Alta Demanda (Core Business):
#
#  Muebles: 1,886 unidades (Líder absoluto de mercado).
#
#  Electrónicos: 1,772 unidades (Segunda fuerza comercial).
#
#  Juguetes: 1,290 unidades
#
#  .Segmentos de Baja Rotación:
#
#  Artículos para el hogar: 730 unidades (Menor penetración)
#
#  Libros y Música: Registran una demanda marginal con 742 y 753 ventas respectivamente.
#
#
#
#  Análisis por sucursal:
#  La Tienda 3 presenta la mayor eficiencia en el sector de Muebles (499 unidades), mientras que la Tienda 1 domina el sector Electrónico. En contraste, los artículos para el hogar muestran una debilidad estructural en todas las locaciones, especialmente en la Tienda 1.
#
# Customer Experience
#
# Se analizó el feedback de los consumidores para medir el prestigio de cada tienda:
#
#
# Tienda 3: 4.05 / 5.0 (Nivel óptimo de satisfacción).
#
# Tienda 2: 4.04 / 5.0
#
# Tienda 4: 4.00 / 5.0
#
# Tienda 1: 3.98 / 5.0 (Margen de mejora detectado).
#
# Conclusión: La Tienda 3 logra la mayor fidelización y aprobación del público, lo que reduce la fricción para el ingreso de nuevas marcas.
#
# Dinámica de Productos: Máximos y MínimosEl inventario muestra comportamientos heterogéneos según la ubicación:
#
# TiendaProducto Estrella (Top Seller) vs Producto de Baja Rotación
#
# Tienda 1
# Armario (60 u.) vs
# Celular ABXY (33 u.)
#
# Tienda 2
# Libro Programación (65 u.) vs
# Juego de mesa (32 u.)
#
# Tienda 3
# Kit de bancas (57 u.) vs
# Bloques construcción (35 u.)
#
# Tienda 4
# Cama box (62 u.) vs
# Guitarra eléctrica (33 u.)
#
# Observación: Existe una fuerte inclinación hacia el mobiliario pesado en las ventas líderes, lo que sugiere un perfil de cliente con alto ticket promedio en las tiendas 1, 3 y 4.
#
#  Análisis de Eficiencia Logística
#
#  Se calculó el impacto financiero del transporte por cada transacción:
#
#  Tienda 4: $23,459.46 (Operación más eficiente).
#
#  Tienda 3: $24,805.68
#
#  Tienda 2: $25,216.24
#
#  Tienda 1: $26,018.61 (Costo logístico más elevado).
#
#  Propuesta Estratégica para el Sr. Juan
#  Tras el cruce de variables, se recomienda la Tienda 3 como la plataforma de lanzamiento prioritaria.
#
#  Justificación Técnica:
#
#  Reputación de Marca: Poseer el mayor índice de satisfacción (4.05%) garantiza un entorno de confianza, vital para que un nuevo producto gane tracción mediante reseñas positivas.
#  Dominio de Categoría: Si la oferta del Sr. Juan se vincula a Muebles, la Tienda 3 es el ecosistema ideal, habiendo demostrado el mayor volumen de ventas (499 unidades) en este rubro.
#
#  Balance Riesgo-Beneficio: Aunque la Tienda 1 factura más, sus altos costos de envío y su menor calificación de clientes representan una barrera de entrada riesgosa.
#
#   La Tienda 3 ofrece el equilibrio perfecto entre volumen de ventas y calidad de servicio, asegurando un crecimiento orgánico y sostenible para el proyecto del Sr. Juan.
